# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import scipy.stats as sts

# %% [markdown]
# # Our Scientific Questioning

# %% [markdown]
# Thanks to the information received by the website https://bigcitieshealthdata.org, we aim to predict the type of death from thanks to data such as the place of living, gender or details about the environment of a person.

# %% [markdown]
# # 1. Data Gathering

# %%
data = pd.read_csv('BigCitiesHealth.csv')

# %%
data
# Out:
#        metric_item_label            metric_cat_label    metric_subcat_label  \
# 0        COVID-19 Deaths         Infectious Diseases  Respiratory Infection
# 1        COVID-19 Deaths         Infectious Diseases  Respiratory Infection
# 2        COVID-19 Deaths         Infectious Diseases  Respiratory Infection
# 3        COVID-19 Deaths         Infectious Diseases  Respiratory Infection
# 4        COVID-19 Deaths         Infectious Diseases  Respiratory Infection
# ...                  ...                         ...                    ...
# 148287   Premature Death  Life Expectancy and Deaths                 Deaths
# 148288   Premature Death  Life Expectancy and Deaths                 Deaths
# 148289   Premature Death  Life Expectancy and Deaths                 Deaths
# 148290   Premature Death  Life Expectancy and Deaths                 Deaths
# 148291   Premature Death  Life Expectancy and Deaths                 Deaths
#
#                                metric_item_label_subtitle  \
# 0       Deaths from COVID-19 (per 100,000 population, ...
# 1       Deaths from COVID-19 (per 100,000 population, ...
# 2       Deaths from COVID-19 (per 100,000 population, ...
# 3       Deaths from COVID-19 (per 100,000 population, ...
# 4       Deaths from COVID-19 (per 100,000 population, ...
# ...                                                   ...
# 148287  Years of potential life lost before age 75 (pe...
# 148288  Years of potential life lost before age 75 (pe...
# 148289  Years of potential life lost before age 75 (pe...
# 148290  Years of potential life lost before age 75 (pe...
# 148291  Years of potential life lost before age 75 (pe...
#
#                   metric_cat_item_yaxis_label  \
# 0                                 Per 100,000
# 1                                 Per 100,000
# 2                                 Per 100,000
# 3                                 Per 100,000
# 4                                 Per 100,000
# ...                                       ...
# 148287  Years per 100,000 population aged <75
# 148288  Years per 100,000 population aged <75
# 148289  Years per 100,000 population aged <75
# 148290  Years per 100,000 population aged <75
# 148291  Years per 100,000 population aged <75
#
#                               metric_source_desc_label_fn  \
# 0       National Vital Statistics System (NVSS), Cente...
# 1       National Vital Statistics System (NVSS), Cente...
# 2       National Vital Statistics System (NVSS), Cente...
# 3       National Vital Statistics System (NVSS), Cente...
# 4       National Vital Statistics System (NVSS), Cente...
# ...                                                   ...
# 148287  National Vital Statistics System (NVSS), Cente...
# 148288  National Vital Statistics System (NVSS), Cente...
# 148289  National Vital Statistics System (NVSS), Cente...
# 148290  National Vital Statistics System (NVSS), Cente...
# 148291  National Vital Statistics System (NVSS), Cente...
#
#                 metric_source_desc_label_url_fn geo_label_city  \
# 0       https://www.cdc.gov/nchs/nvss/index.htm         Dallas
# 1       https://www.cdc.gov/nchs/nvss/index.htm     Fort Worth
# 2       https://www.cdc.gov/nchs/nvss/index.htm    San Antonio
# 3       https://www.cdc.gov/nchs/nvss/index.htm        Chicago
# 4       https://www.cdc.gov/nchs/nvss/index.htm    Kansas City
# ...                                         ...            ...
# 148287  https://www.cdc.gov/nchs/nvss/index.htm  New York City
# 148288  https://www.cdc.gov/nchs/nvss/index.htm      Milwaukee
# 148289  https://www.cdc.gov/nchs/nvss/index.htm        Houston
# 148290  https://www.cdc.gov/nchs/nvss/index.htm      Milwaukee
# 148291  https://www.cdc.gov/nchs/nvss/index.htm     Long Beach
#
#        geo_label_state geo_label_citystate  ...  value_90_ci_low  \
# 0                   TX          Dallas, TX  ...              NaN
# 1                   TX      Fort Worth, TX  ...              NaN
# 2                   TX     San Antonio, TX  ...              NaN
# 3                   IL         Chicago, IL  ...              NaN
# 4                   MO     Kansas City, MO  ...              NaN
# ...                ...                 ...  ...              ...
# 148287              NY   New York City, NY  ...              NaN
# 148288              WI       Milwaukee, WI  ...              NaN
# 148289              TX         Houston, TX  ...              NaN
# 148290              WI       Milwaukee, WI  ...              NaN
# 148291              CA      Long Beach, CA  ...              NaN
#
#         value_90_ci_high  geo_strata_region            geo_strata_poverty  \
# 0                    NaN              South  Less poor cities (<20% poor)
# 1                    NaN              South  Less poor cities (<20% poor)
# 2                    NaN              South  Less poor cities (<20% poor)
# 3                    NaN            Midwest  Less poor cities (<20% poor)
# 4                    NaN            Midwest  Less poor cities (<20% poor)
# ...                  ...                ...                           ...
# 148287               NaN          Northeast  Less poor cities (<20% poor)
# 148288               NaN            Midwest    Poorest cities (20%+ poor)
# 148289               NaN              South  Less poor cities (<20% poor)
# 148290               NaN            Midwest    Poorest cities (20%+ poor)
# 148291               NaN               West  Less poor cities (<20% poor)
#
#          geo_strata_Population                  geo_strata_PopDensity  \
# 0       Largest (>1.3 million)    Lower pop. density (<10k per sq mi)
# 1       Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# 2       Largest (>1.3 million)    Lower pop. density (<10k per sq mi)
# 3       Largest (>1.3 million)  Highest pop. density (>10k per sq mi)
# 4       Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# ...                        ...                                    ...
# 148287  Largest (>1.3 million)  Highest pop. density (>10k per sq mi)
# 148288  Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# 148289  Largest (>1.3 million)    Lower pop. density (<10k per sq mi)
# 148290  Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# 148291  Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
#
#           geo_strata_Segregation strata_race_label strata_sex_label  \
# 0       Highly Segregated (50%+)          Hispanic             Male
# 1         Less Segregated (<50%)          Asian/PI             Male
# 2         Less Segregated (<50%)             White             Male
# 3       Highly Segregated (50%+)          Hispanic             Male
# 4         Less Segregated (<50%)          Hispanic             Male
# ...                          ...               ...              ...
# 148287  Highly Segregated (50%+)          Hispanic             Both
# 148288  Highly Segregated (50%+)          Hispanic             Both
# 148289  Highly Segregated (50%+)          Asian/PI             Both
# 148290  Highly Segregated (50%+)          Asian/PI             Both
# 148291  Highly Segregated (50%+)          Asian/PI             Both
#
#         strata_race_sex_label
# 0               Hispanic Male
# 1               Asian/PI Male
# 2                  White Male
# 3               Hispanic Male
# 4               Hispanic Male
# ...                       ...
# 148287                    NaN
# 148288                    NaN
# 148289                    NaN
# 148290                    NaN
# 148291                    NaN
#
# [148292 rows x 31 columns]

# %% [markdown]
# Get data information such as data types, shape etc.

# %%
data.shape
# Out:
# (148292, 31)

# %%
data.dtypes
# Out:
# metric_item_label                   object
# metric_cat_label                    object
# metric_subcat_label                 object
# metric_item_label_subtitle          object
# metric_cat_item_yaxis_label         object
# metric_source_desc_label_fn         object
# metric_source_desc_label_url_fn     object
# geo_label_city                      object
# geo_label_state                     object
# geo_label_citystate                 object
# geo_fips_code                      float64
# value                              float64
# date_label                           int64
# geo_label_proxy_or_real             object
# geo_label_proxy_footnote            object
# geo_fips_desc                       object
# date_label_proxy_or_real            object
# date_label_proxy_footnote           object
# value_ci_flag_yesno                 object
# value_95_ci_low                    float64
# value_95_ci_high                   float64
# value_90_ci_low                    float64
# value_90_ci_high                   float64
# geo_strata_region                   object
# geo_strata_poverty                  object
# geo_strata_Population               object
# geo_strata_PopDensity               object
# geo_strata_Segregation              object
# strata_race_label                   object
# strata_sex_label                    object
# strata_race_sex_label               object
# dtype: object

# %% [markdown]
# # 2. Data PreProcessing

# %% [markdown]
# We can see the different types of deaths possible from our data

# %%
death_rows = data[data['metric_subcat_label'].str.contains('death', case=False)]
death_rows['metric_item_label'].value_counts()
# Out:
# Premature Death                        5775
# Deaths from All Causes                 5371
# Injury Deaths                          5173
# Motor Vehicle Deaths                   4313
# Firearm Deaths                         4092
# Police Killings                        1496
# Infant Deaths                          1152
# Maternal Deaths                         770
# Racial Disparity in Police Killings     374
# Name: metric_item_label, dtype: int64

# %% [markdown]
# So we will only keep the rows that interest us which are the rows where there is 'death' in the metric_subcat_label column

# %%
data_death_only = data[data['metric_subcat_label'].str.contains('death', case=False)]
data_death_only
# Out:
#              metric_item_label            metric_cat_label  \
# 5106    Deaths from All Causes  Life Expectancy and Deaths
# 5107    Deaths from All Causes  Life Expectancy and Deaths
# 5108    Deaths from All Causes  Life Expectancy and Deaths
# 5109    Deaths from All Causes  Life Expectancy and Deaths
# 5110    Deaths from All Causes  Life Expectancy and Deaths
# ...                        ...                         ...
# 148287         Premature Death  Life Expectancy and Deaths
# 148288         Premature Death  Life Expectancy and Deaths
# 148289         Premature Death  Life Expectancy and Deaths
# 148290         Premature Death  Life Expectancy and Deaths
# 148291         Premature Death  Life Expectancy and Deaths
#
#        metric_subcat_label                         metric_item_label_subtitle  \
# 5106                Deaths  Deaths from all causes (per 100,000 population...
# 5107                Deaths  Deaths from all causes (per 100,000 population...
# 5108                Deaths  Deaths from all causes (per 100,000 population...
# 5109                Deaths  Deaths from all causes (per 100,000 population...
# 5110                Deaths  Deaths from all causes (per 100,000 population...
# ...                    ...                                                ...
# 148287              Deaths  Years of potential life lost before age 75 (pe...
# 148288              Deaths  Years of potential life lost before age 75 (pe...
# 148289              Deaths  Years of potential life lost before age 75 (pe...
# 148290              Deaths  Years of potential life lost before age 75 (pe...
# 148291              Deaths  Years of potential life lost before age 75 (pe...
#
#                   metric_cat_item_yaxis_label  \
# 5106                              Per 100,000
# 5107                              Per 100,000
# 5108                              Per 100,000
# 5109                              Per 100,000
# 5110                              Per 100,000
# ...                                       ...
# 148287  Years per 100,000 population aged <75
# 148288  Years per 100,000 population aged <75
# 148289  Years per 100,000 population aged <75
# 148290  Years per 100,000 population aged <75
# 148291  Years per 100,000 population aged <75
#
#                               metric_source_desc_label_fn  \
# 5106    National Vital Statistics System (NVSS), Cente...
# 5107    National Vital Statistics System (NVSS), Cente...
# 5108    National Vital Statistics System (NVSS), Cente...
# 5109    National Vital Statistics System (NVSS), Cente...
# 5110    National Vital Statistics System (NVSS), Cente...
# ...                                                   ...
# 148287  National Vital Statistics System (NVSS), Cente...
# 148288  National Vital Statistics System (NVSS), Cente...
# 148289  National Vital Statistics System (NVSS), Cente...
# 148290  National Vital Statistics System (NVSS), Cente...
# 148291  National Vital Statistics System (NVSS), Cente...
#
#                 metric_source_desc_label_url_fn geo_label_city  \
# 5106    https://www.cdc.gov/nchs/nvss/index.htm        Seattle
# 5107    https://www.cdc.gov/nchs/nvss/index.htm     Fort Worth
# 5108    https://www.cdc.gov/nchs/nvss/index.htm  Oklahoma City
# 5109    https://www.cdc.gov/nchs/nvss/index.htm     Long Beach
# 5110    https://www.cdc.gov/nchs/nvss/index.htm       Columbus
# ...                                         ...            ...
# 148287  https://www.cdc.gov/nchs/nvss/index.htm  New York City
# 148288  https://www.cdc.gov/nchs/nvss/index.htm      Milwaukee
# 148289  https://www.cdc.gov/nchs/nvss/index.htm        Houston
# 148290  https://www.cdc.gov/nchs/nvss/index.htm      Milwaukee
# 148291  https://www.cdc.gov/nchs/nvss/index.htm     Long Beach
#
#        geo_label_state geo_label_citystate  ...  value_90_ci_low  \
# 5106                WA         Seattle, WA  ...              NaN
# 5107                TX      Fort Worth, TX  ...              NaN
# 5108                OK   Oklahoma City, OK  ...              NaN
# 5109                CA      Long Beach, CA  ...              NaN
# 5110                OH        Columbus, OH  ...              NaN
# ...                ...                 ...  ...              ...
# 148287              NY   New York City, NY  ...              NaN
# 148288              WI       Milwaukee, WI  ...              NaN
# 148289              TX         Houston, TX  ...              NaN
# 148290              WI       Milwaukee, WI  ...              NaN
# 148291              CA      Long Beach, CA  ...              NaN
#
#         value_90_ci_high  geo_strata_region            geo_strata_poverty  \
# 5106                 NaN               West  Less poor cities (<20% poor)
# 5107                 NaN              South  Less poor cities (<20% poor)
# 5108                 NaN              South  Less poor cities (<20% poor)
# 5109                 NaN               West  Less poor cities (<20% poor)
# 5110                 NaN            Midwest  Less poor cities (<20% poor)
# ...                  ...                ...                           ...
# 148287               NaN          Northeast  Less poor cities (<20% poor)
# 148288               NaN            Midwest    Poorest cities (20%+ poor)
# 148289               NaN              South  Less poor cities (<20% poor)
# 148290               NaN            Midwest    Poorest cities (20%+ poor)
# 148291               NaN               West  Less poor cities (<20% poor)
#
#          geo_strata_Population                  geo_strata_PopDensity  \
# 5106    Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# 5107    Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# 5108    Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# 5109    Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# 5110    Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# ...                        ...                                    ...
# 148287  Largest (>1.3 million)  Highest pop. density (>10k per sq mi)
# 148288  Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# 148289  Largest (>1.3 million)    Lower pop. density (<10k per sq mi)
# 148290  Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# 148291  Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
#
#           geo_strata_Segregation strata_race_label strata_sex_label  \
# 5106      Less Segregated (<50%)          Asian/PI             Both
# 5107      Less Segregated (<50%)               All             Male
# 5108      Less Segregated (<50%)          Asian/PI             Both
# 5109    Highly Segregated (50%+)          Asian/PI             Both
# 5110      Less Segregated (<50%)             Black             Male
# ...                          ...               ...              ...
# 148287  Highly Segregated (50%+)          Hispanic             Both
# 148288  Highly Segregated (50%+)          Hispanic             Both
# 148289  Highly Segregated (50%+)          Asian/PI             Both
# 148290  Highly Segregated (50%+)          Asian/PI             Both
# 148291  Highly Segregated (50%+)          Asian/PI             Both
#
#         strata_race_sex_label
# 5106                      NaN
# 5107                      NaN
# 5108                      NaN
# 5109                      NaN
# 5110               Black Male
# ...                       ...
# 148287                    NaN
# 148288                    NaN
# 148289                    NaN
# 148290                    NaN
# 148291                    NaN
#
# [28516 rows x 31 columns]

# %% [markdown]
# In this step, the goal is to drop non-relevant columns or rows, in order to get a clean and non-missing item data.

# %%
data_death_only.isnull().sum()
# Out:
# metric_item_label                      0
# metric_cat_label                       0
# metric_subcat_label                    0
# metric_item_label_subtitle             0
# metric_cat_item_yaxis_label            0
# metric_source_desc_label_fn            0
# metric_source_desc_label_url_fn        0
# geo_label_city                         0
# geo_label_state                       62
# geo_label_citystate                    0
# geo_fips_code                         62
# value                                308
# date_label                             0
# geo_label_proxy_or_real                0
# geo_label_proxy_footnote           27030
# geo_fips_desc                          0
# date_label_proxy_or_real               0
# date_label_proxy_footnote          28006
# value_ci_flag_yesno                    0
# value_95_ci_low                     1942
# value_95_ci_high                    1932
# value_90_ci_low                    28516
# value_90_ci_high                   28516
# geo_strata_region                     62
# geo_strata_poverty                    62
# geo_strata_Population                 62
# geo_strata_PopDensity                 62
# geo_strata_Segregation                62
# strata_race_label                      0
# strata_sex_label                       0
# strata_race_sex_label              16449
# dtype: int64

# %% [markdown]
# Dropping data from rows with a too high amount of missing values (more than 50% of data length)

# %%
threshold = len(data_death_only) * 0.5
data_death_only = data_death_only.dropna(thresh=threshold, axis=1)

# %%
len(data_death_only)
# Out:
# 28516

# %%
data_death_only.isnull().sum()
# Out:
# metric_item_label                     0
# metric_cat_label                      0
# metric_subcat_label                   0
# metric_item_label_subtitle            0
# metric_cat_item_yaxis_label           0
# metric_source_desc_label_fn           0
# metric_source_desc_label_url_fn       0
# geo_label_city                        0
# geo_label_state                      62
# geo_label_citystate                   0
# geo_fips_code                        62
# value                               308
# date_label                            0
# geo_label_proxy_or_real               0
# geo_fips_desc                         0
# date_label_proxy_or_real              0
# value_ci_flag_yesno                   0
# value_95_ci_low                    1942
# value_95_ci_high                   1932
# geo_strata_region                    62
# geo_strata_poverty                   62
# geo_strata_Population                62
# geo_strata_PopDensity                62
# geo_strata_Segregation               62
# strata_race_label                     0
# strata_sex_label                      0
# dtype: int64

# %% [markdown]
# There seem to be several columns with the same missing rows, so it makes sense to suppress them

# %%
data_death_only = data_death_only.dropna(subset=['geo_label_state'])
data_death_only.isnull().sum()
# Out:
# metric_item_label                     0
# metric_cat_label                      0
# metric_subcat_label                   0
# metric_item_label_subtitle            0
# metric_cat_item_yaxis_label           0
# metric_source_desc_label_fn           0
# metric_source_desc_label_url_fn       0
# geo_label_city                        0
# geo_label_state                       0
# geo_label_citystate                   0
# geo_fips_code                         0
# value                               308
# date_label                            0
# geo_label_proxy_or_real               0
# geo_fips_desc                         0
# date_label_proxy_or_real              0
# value_ci_flag_yesno                   0
# value_95_ci_low                    1880
# value_95_ci_high                   1870
# geo_strata_region                     0
# geo_strata_poverty                    0
# geo_strata_Population                 0
# geo_strata_PopDensity                 0
# geo_strata_Segregation                0
# strata_race_label                     0
# strata_sex_label                      0
# dtype: int64

# %% [markdown]
# Also thosw with missing ci_95 high/low values

# %%
data_death_only = data_death_only.dropna(subset=['value_95_ci_low'])
data_death_only.isnull().sum()
# Out:
# metric_item_label                  0
# metric_cat_label                   0
# metric_subcat_label                0
# metric_item_label_subtitle         0
# metric_cat_item_yaxis_label        0
# metric_source_desc_label_fn        0
# metric_source_desc_label_url_fn    0
# geo_label_city                     0
# geo_label_state                    0
# geo_label_citystate                0
# geo_fips_code                      0
# value                              0
# date_label                         0
# geo_label_proxy_or_real            0
# geo_fips_desc                      0
# date_label_proxy_or_real           0
# value_ci_flag_yesno                0
# value_95_ci_low                    0
# value_95_ci_high                   0
# geo_strata_region                  0
# geo_strata_poverty                 0
# geo_strata_Population              0
# geo_strata_PopDensity              0
# geo_strata_Segregation             0
# strata_race_label                  0
# strata_sex_label                   0
# dtype: int64

# %% [markdown]
# No more missing values! Now lets look at our data. Are there still columns that we don't need?

# %%
data_death_only
# Out:
#              metric_item_label            metric_cat_label  \
# 5106    Deaths from All Causes  Life Expectancy and Deaths
# 5107    Deaths from All Causes  Life Expectancy and Deaths
# 5108    Deaths from All Causes  Life Expectancy and Deaths
# 5109    Deaths from All Causes  Life Expectancy and Deaths
# 5110    Deaths from All Causes  Life Expectancy and Deaths
# ...                        ...                         ...
# 148287         Premature Death  Life Expectancy and Deaths
# 148288         Premature Death  Life Expectancy and Deaths
# 148289         Premature Death  Life Expectancy and Deaths
# 148290         Premature Death  Life Expectancy and Deaths
# 148291         Premature Death  Life Expectancy and Deaths
#
#        metric_subcat_label                         metric_item_label_subtitle  \
# 5106                Deaths  Deaths from all causes (per 100,000 population...
# 5107                Deaths  Deaths from all causes (per 100,000 population...
# 5108                Deaths  Deaths from all causes (per 100,000 population...
# 5109                Deaths  Deaths from all causes (per 100,000 population...
# 5110                Deaths  Deaths from all causes (per 100,000 population...
# ...                    ...                                                ...
# 148287              Deaths  Years of potential life lost before age 75 (pe...
# 148288              Deaths  Years of potential life lost before age 75 (pe...
# 148289              Deaths  Years of potential life lost before age 75 (pe...
# 148290              Deaths  Years of potential life lost before age 75 (pe...
# 148291              Deaths  Years of potential life lost before age 75 (pe...
#
#                   metric_cat_item_yaxis_label  \
# 5106                              Per 100,000
# 5107                              Per 100,000
# 5108                              Per 100,000
# 5109                              Per 100,000
# 5110                              Per 100,000
# ...                                       ...
# 148287  Years per 100,000 population aged <75
# 148288  Years per 100,000 population aged <75
# 148289  Years per 100,000 population aged <75
# 148290  Years per 100,000 population aged <75
# 148291  Years per 100,000 population aged <75
#
#                               metric_source_desc_label_fn  \
# 5106    National Vital Statistics System (NVSS), Cente...
# 5107    National Vital Statistics System (NVSS), Cente...
# 5108    National Vital Statistics System (NVSS), Cente...
# 5109    National Vital Statistics System (NVSS), Cente...
# 5110    National Vital Statistics System (NVSS), Cente...
# ...                                                   ...
# 148287  National Vital Statistics System (NVSS), Cente...
# 148288  National Vital Statistics System (NVSS), Cente...
# 148289  National Vital Statistics System (NVSS), Cente...
# 148290  National Vital Statistics System (NVSS), Cente...
# 148291  National Vital Statistics System (NVSS), Cente...
#
#                 metric_source_desc_label_url_fn geo_label_city  \
# 5106    https://www.cdc.gov/nchs/nvss/index.htm        Seattle
# 5107    https://www.cdc.gov/nchs/nvss/index.htm     Fort Worth
# 5108    https://www.cdc.gov/nchs/nvss/index.htm  Oklahoma City
# 5109    https://www.cdc.gov/nchs/nvss/index.htm     Long Beach
# 5110    https://www.cdc.gov/nchs/nvss/index.htm       Columbus
# ...                                         ...            ...
# 148287  https://www.cdc.gov/nchs/nvss/index.htm  New York City
# 148288  https://www.cdc.gov/nchs/nvss/index.htm      Milwaukee
# 148289  https://www.cdc.gov/nchs/nvss/index.htm        Houston
# 148290  https://www.cdc.gov/nchs/nvss/index.htm      Milwaukee
# 148291  https://www.cdc.gov/nchs/nvss/index.htm     Long Beach
#
#        geo_label_state geo_label_citystate  ...  value_ci_flag_yesno  \
# 5106                WA         Seattle, WA  ...                  yes
# 5107                TX      Fort Worth, TX  ...                  yes
# 5108                OK   Oklahoma City, OK  ...                  yes
# 5109                CA      Long Beach, CA  ...                  yes
# 5110                OH        Columbus, OH  ...                  yes
# ...                ...                 ...  ...                  ...
# 148287              NY   New York City, NY  ...                  yes
# 148288              WI       Milwaukee, WI  ...                  yes
# 148289              TX         Houston, TX  ...                  yes
# 148290              WI       Milwaukee, WI  ...                  yes
# 148291              CA      Long Beach, CA  ...                  yes
#
#         value_95_ci_low  value_95_ci_high geo_strata_region  \
# 5106         461.008945        513.234238              West
# 5107         954.331095       1002.484873             South
# 5108         320.748770        439.341284             South
# 5109         579.671889        655.777365              West
# 5110         992.238894       1106.836430           Midwest
# ...                 ...               ...               ...
# 148287      5668.487295       5903.948459         Northeast
# 148288      6458.346917       7717.512570           Midwest
# 148289      3723.288703       4475.407910             South
# 148290      4594.357077       6818.700061           Midwest
# 148291      4696.310360       5936.085707              West
#
#                   geo_strata_poverty   geo_strata_Population  \
# 5106    Less poor cities (<20% poor)  Smaller (<1.3 million)
# 5107    Less poor cities (<20% poor)  Smaller (<1.3 million)
# 5108    Less poor cities (<20% poor)  Smaller (<1.3 million)
# 5109    Less poor cities (<20% poor)  Smaller (<1.3 million)
# 5110    Less poor cities (<20% poor)  Smaller (<1.3 million)
# ...                              ...                     ...
# 148287  Less poor cities (<20% poor)  Largest (>1.3 million)
# 148288    Poorest cities (20%+ poor)  Smaller (<1.3 million)
# 148289  Less poor cities (<20% poor)  Largest (>1.3 million)
# 148290    Poorest cities (20%+ poor)  Smaller (<1.3 million)
# 148291  Less poor cities (<20% poor)  Smaller (<1.3 million)
#
#                         geo_strata_PopDensity    geo_strata_Segregation  \
# 5106      Lower pop. density (<10k per sq mi)    Less Segregated (<50%)
# 5107      Lower pop. density (<10k per sq mi)    Less Segregated (<50%)
# 5108      Lower pop. density (<10k per sq mi)    Less Segregated (<50%)
# 5109      Lower pop. density (<10k per sq mi)  Highly Segregated (50%+)
# 5110      Lower pop. density (<10k per sq mi)    Less Segregated (<50%)
# ...                                       ...                       ...
# 148287  Highest pop. density (>10k per sq mi)  Highly Segregated (50%+)
# 148288    Lower pop. density (<10k per sq mi)  Highly Segregated (50%+)
# 148289    Lower pop. density (<10k per sq mi)  Highly Segregated (50%+)
# 148290    Lower pop. density (<10k per sq mi)  Highly Segregated (50%+)
# 148291    Lower pop. density (<10k per sq mi)  Highly Segregated (50%+)
#
#         strata_race_label strata_sex_label
# 5106             Asian/PI             Both
# 5107                  All             Male
# 5108             Asian/PI             Both
# 5109             Asian/PI             Both
# 5110                Black             Male
# ...                   ...              ...
# 148287           Hispanic             Both
# 148288           Hispanic             Both
# 148289           Asian/PI             Both
# 148290           Asian/PI             Both
# 148291           Asian/PI             Both
#
# [26574 rows x 26 columns]

# %%
data_death_only = data_death_only.drop(['metric_source_desc_label_fn', 'metric_source_desc_label_url_fn', 'geo_label_citystate'], axis=1)

# %% [markdown]
# Our data seems clear now!

# %%
data_death_only
# Out:
#              metric_item_label            metric_cat_label  \
# 5106    Deaths from All Causes  Life Expectancy and Deaths
# 5107    Deaths from All Causes  Life Expectancy and Deaths
# 5108    Deaths from All Causes  Life Expectancy and Deaths
# 5109    Deaths from All Causes  Life Expectancy and Deaths
# 5110    Deaths from All Causes  Life Expectancy and Deaths
# ...                        ...                         ...
# 148287         Premature Death  Life Expectancy and Deaths
# 148288         Premature Death  Life Expectancy and Deaths
# 148289         Premature Death  Life Expectancy and Deaths
# 148290         Premature Death  Life Expectancy and Deaths
# 148291         Premature Death  Life Expectancy and Deaths
#
#        metric_subcat_label                         metric_item_label_subtitle  \
# 5106                Deaths  Deaths from all causes (per 100,000 population...
# 5107                Deaths  Deaths from all causes (per 100,000 population...
# 5108                Deaths  Deaths from all causes (per 100,000 population...
# 5109                Deaths  Deaths from all causes (per 100,000 population...
# 5110                Deaths  Deaths from all causes (per 100,000 population...
# ...                    ...                                                ...
# 148287              Deaths  Years of potential life lost before age 75 (pe...
# 148288              Deaths  Years of potential life lost before age 75 (pe...
# 148289              Deaths  Years of potential life lost before age 75 (pe...
# 148290              Deaths  Years of potential life lost before age 75 (pe...
# 148291              Deaths  Years of potential life lost before age 75 (pe...
#
#                   metric_cat_item_yaxis_label geo_label_city geo_label_state  \
# 5106                              Per 100,000        Seattle              WA
# 5107                              Per 100,000     Fort Worth              TX
# 5108                              Per 100,000  Oklahoma City              OK
# 5109                              Per 100,000     Long Beach              CA
# 5110                              Per 100,000       Columbus              OH
# ...                                       ...            ...             ...
# 148287  Years per 100,000 population aged <75  New York City              NY
# 148288  Years per 100,000 population aged <75      Milwaukee              WI
# 148289  Years per 100,000 population aged <75        Houston              TX
# 148290  Years per 100,000 population aged <75      Milwaukee              WI
# 148291  Years per 100,000 population aged <75     Long Beach              CA
#
#         geo_fips_code        value  date_label  ... value_ci_flag_yesno  \
# 5106        5363000.0   486.350121        2012  ...                 yes
# 5107        4827000.0   978.155993        2011  ...                 yes
# 5108        4055000.0   376.240836        2012  ...                 yes
# 5109         643000.0   616.697165        2012  ...                 yes
# 5110        3918000.0  1048.217766        2010  ...                 yes
# ...               ...          ...         ...  ...                 ...
# 148287      3651000.0  5786.217877        2020  ...                 yes
# 148288      5553000.0  7087.929743        2020  ...                 yes
# 148289      4835000.0  4099.348306        2011  ...                 yes
# 148290      5553000.0  5706.528569        2014  ...                 yes
# 148291       643000.0  5316.198034        2015  ...                 yes
#
#        value_95_ci_low value_95_ci_high geo_strata_region  \
# 5106        461.008945       513.234238              West
# 5107        954.331095      1002.484873             South
# 5108        320.748770       439.341284             South
# 5109        579.671889       655.777365              West
# 5110        992.238894      1106.836430           Midwest
# ...                ...              ...               ...
# 148287     5668.487295      5903.948459         Northeast
# 148288     6458.346917      7717.512570           Midwest
# 148289     3723.288703      4475.407910             South
# 148290     4594.357077      6818.700061           Midwest
# 148291     4696.310360      5936.085707              West
#
#                   geo_strata_poverty   geo_strata_Population  \
# 5106    Less poor cities (<20% poor)  Smaller (<1.3 million)
# 5107    Less poor cities (<20% poor)  Smaller (<1.3 million)
# 5108    Less poor cities (<20% poor)  Smaller (<1.3 million)
# 5109    Less poor cities (<20% poor)  Smaller (<1.3 million)
# 5110    Less poor cities (<20% poor)  Smaller (<1.3 million)
# ...                              ...                     ...
# 148287  Less poor cities (<20% poor)  Largest (>1.3 million)
# 148288    Poorest cities (20%+ poor)  Smaller (<1.3 million)
# 148289  Less poor cities (<20% poor)  Largest (>1.3 million)
# 148290    Poorest cities (20%+ poor)  Smaller (<1.3 million)
# 148291  Less poor cities (<20% poor)  Smaller (<1.3 million)
#
#                         geo_strata_PopDensity    geo_strata_Segregation  \
# 5106      Lower pop. density (<10k per sq mi)    Less Segregated (<50%)
# 5107      Lower pop. density (<10k per sq mi)    Less Segregated (<50%)
# 5108      Lower pop. density (<10k per sq mi)    Less Segregated (<50%)
# 5109      Lower pop. density (<10k per sq mi)  Highly Segregated (50%+)
# 5110      Lower pop. density (<10k per sq mi)    Less Segregated (<50%)
# ...                                       ...                       ...
# 148287  Highest pop. density (>10k per sq mi)  Highly Segregated (50%+)
# 148288    Lower pop. density (<10k per sq mi)  Highly Segregated (50%+)
# 148289    Lower pop. density (<10k per sq mi)  Highly Segregated (50%+)
# 148290    Lower pop. density (<10k per sq mi)  Highly Segregated (50%+)
# 148291    Lower pop. density (<10k per sq mi)  Highly Segregated (50%+)
#
#        strata_race_label strata_sex_label
# 5106            Asian/PI             Both
# 5107                 All             Male
# 5108            Asian/PI             Both
# 5109            Asian/PI             Both
# 5110               Black             Male
# ...                  ...              ...
# 148287          Hispanic             Both
# 148288          Hispanic             Both
# 148289          Asian/PI             Both
# 148290          Asian/PI             Both
# 148291          Asian/PI             Both
#
# [26574 rows x 23 columns]

# %%
data = data_death_only

# %% [markdown]
# # 3. Exploratory Data Analysis

# %% [markdown]
# We want to visualize and find relationships between the metrics using statistical methods.

# %% [markdown]
# Drop also the labels that we don't need anymore or that only have one type of input

# %%
data = data.drop(['metric_subcat_label', 'value_ci_flag_yesno', 'geo_fips_desc', 'date_label_proxy_or_real'], axis = 1)

# %%
data
# Out:
#              metric_item_label            metric_cat_label  \
# 5106    Deaths from All Causes  Life Expectancy and Deaths
# 5107    Deaths from All Causes  Life Expectancy and Deaths
# 5108    Deaths from All Causes  Life Expectancy and Deaths
# 5109    Deaths from All Causes  Life Expectancy and Deaths
# 5110    Deaths from All Causes  Life Expectancy and Deaths
# ...                        ...                         ...
# 148287         Premature Death  Life Expectancy and Deaths
# 148288         Premature Death  Life Expectancy and Deaths
# 148289         Premature Death  Life Expectancy and Deaths
# 148290         Premature Death  Life Expectancy and Deaths
# 148291         Premature Death  Life Expectancy and Deaths
#
#                                metric_item_label_subtitle  \
# 5106    Deaths from all causes (per 100,000 population...
# 5107    Deaths from all causes (per 100,000 population...
# 5108    Deaths from all causes (per 100,000 population...
# 5109    Deaths from all causes (per 100,000 population...
# 5110    Deaths from all causes (per 100,000 population...
# ...                                                   ...
# 148287  Years of potential life lost before age 75 (pe...
# 148288  Years of potential life lost before age 75 (pe...
# 148289  Years of potential life lost before age 75 (pe...
# 148290  Years of potential life lost before age 75 (pe...
# 148291  Years of potential life lost before age 75 (pe...
#
#                   metric_cat_item_yaxis_label geo_label_city geo_label_state  \
# 5106                              Per 100,000        Seattle              WA
# 5107                              Per 100,000     Fort Worth              TX
# 5108                              Per 100,000  Oklahoma City              OK
# 5109                              Per 100,000     Long Beach              CA
# 5110                              Per 100,000       Columbus              OH
# ...                                       ...            ...             ...
# 148287  Years per 100,000 population aged <75  New York City              NY
# 148288  Years per 100,000 population aged <75      Milwaukee              WI
# 148289  Years per 100,000 population aged <75        Houston              TX
# 148290  Years per 100,000 population aged <75      Milwaukee              WI
# 148291  Years per 100,000 population aged <75     Long Beach              CA
#
#         geo_fips_code        value  date_label geo_label_proxy_or_real  \
# 5106        5363000.0   486.350121        2012                    real
# 5107        4827000.0   978.155993        2011                    real
# 5108        4055000.0   376.240836        2012                    real
# 5109         643000.0   616.697165        2012                    real
# 5110        3918000.0  1048.217766        2010                    real
# ...               ...          ...         ...                     ...
# 148287      3651000.0  5786.217877        2020                    real
# 148288      5553000.0  7087.929743        2020                    real
# 148289      4835000.0  4099.348306        2011                    real
# 148290      5553000.0  5706.528569        2014                    real
# 148291       643000.0  5316.198034        2015                    real
#
#         value_95_ci_low  value_95_ci_high geo_strata_region  \
# 5106         461.008945        513.234238              West
# 5107         954.331095       1002.484873             South
# 5108         320.748770        439.341284             South
# 5109         579.671889        655.777365              West
# 5110         992.238894       1106.836430           Midwest
# ...                 ...               ...               ...
# 148287      5668.487295       5903.948459         Northeast
# 148288      6458.346917       7717.512570           Midwest
# 148289      3723.288703       4475.407910             South
# 148290      4594.357077       6818.700061           Midwest
# 148291      4696.310360       5936.085707              West
#
#                   geo_strata_poverty   geo_strata_Population  \
# 5106    Less poor cities (<20% poor)  Smaller (<1.3 million)
# 5107    Less poor cities (<20% poor)  Smaller (<1.3 million)
# 5108    Less poor cities (<20% poor)  Smaller (<1.3 million)
# 5109    Less poor cities (<20% poor)  Smaller (<1.3 million)
# 5110    Less poor cities (<20% poor)  Smaller (<1.3 million)
# ...                              ...                     ...
# 148287  Less poor cities (<20% poor)  Largest (>1.3 million)
# 148288    Poorest cities (20%+ poor)  Smaller (<1.3 million)
# 148289  Less poor cities (<20% poor)  Largest (>1.3 million)
# 148290    Poorest cities (20%+ poor)  Smaller (<1.3 million)
# 148291  Less poor cities (<20% poor)  Smaller (<1.3 million)
#
#                         geo_strata_PopDensity    geo_strata_Segregation  \
# 5106      Lower pop. density (<10k per sq mi)    Less Segregated (<50%)
# 5107      Lower pop. density (<10k per sq mi)    Less Segregated (<50%)
# 5108      Lower pop. density (<10k per sq mi)    Less Segregated (<50%)
# 5109      Lower pop. density (<10k per sq mi)  Highly Segregated (50%+)
# 5110      Lower pop. density (<10k per sq mi)    Less Segregated (<50%)
# ...                                       ...                       ...
# 148287  Highest pop. density (>10k per sq mi)  Highly Segregated (50%+)
# 148288    Lower pop. density (<10k per sq mi)  Highly Segregated (50%+)
# 148289    Lower pop. density (<10k per sq mi)  Highly Segregated (50%+)
# 148290    Lower pop. density (<10k per sq mi)  Highly Segregated (50%+)
# 148291    Lower pop. density (<10k per sq mi)  Highly Segregated (50%+)
#
#        strata_race_label strata_sex_label
# 5106            Asian/PI             Both
# 5107                 All             Male
# 5108            Asian/PI             Both
# 5109            Asian/PI             Both
# 5110               Black             Male
# ...                  ...              ...
# 148287          Hispanic             Both
# 148288          Hispanic             Both
# 148289          Asian/PI             Both
# 148290          Asian/PI             Both
# 148291          Asian/PI             Both
#
# [26574 rows x 19 columns]

# %% [markdown]
# We can divide the geo_fips_code by 1'000 to get realistic values

# %%
data['geo_fips_code'] = data['geo_fips_code'] / 1000

# %% [markdown]
# We have some binary columns, lets transform them to bools

# %%
data.nunique()
# Out:
# metric_item_label                  7
# metric_cat_label                   3
# metric_item_label_subtitle         7
# metric_cat_item_yaxis_label        3
# geo_label_city                    35
# geo_label_state                   23
# geo_fips_code                     35
# value                          25883
# date_label                        11
# geo_label_proxy_or_real            2
# value_95_ci_low                25883
# value_95_ci_high               25883
# geo_strata_region                  4
# geo_strata_poverty                 2
# geo_strata_Population              2
# geo_strata_PopDensity              2
# geo_strata_Segregation             2
# strata_race_label                  5
# strata_sex_label                   3
# dtype: int64

# %%
data['geo_strata_poverty'] = data['geo_strata_poverty'].map({'Less poor cities (<20% poor)': 1, 'Poorest cities (20%+ poor)': 0})

data['geo_strata_Population'] = data['geo_strata_Population'].map({'Smaller (<1.3 million)': 1, 'Largest (>1.3 million)': 0})

data['geo_strata_PopDensity'] = data['geo_strata_PopDensity'].map({'Lower pop. density (<10k per sq mi)': 1, 'Highest pop. density (>10k per sq mi)': 0})

data['geo_strata_Segregation'] = data['geo_strata_Segregation'].map({'Less Segregated (<50%)': 1, 'Highly Segregated (50%+)': 0})

data['geo_label_proxy_or_real'] = data['geo_label_proxy_or_real'].map({'real': 1, 'proxy': 0})

# %%
data.dtypes
# Out:
# metric_item_label               object
# metric_cat_label                object
# metric_item_label_subtitle      object
# metric_cat_item_yaxis_label     object
# geo_label_city                  object
# geo_label_state                 object
# geo_fips_code                  float64
# value                          float64
# date_label                       int64
# geo_label_proxy_or_real          int64
# value_95_ci_low                float64
# value_95_ci_high               float64
# geo_strata_region               object
# geo_strata_poverty               int64
# geo_strata_Population            int64
# geo_strata_PopDensity            int64
# geo_strata_Segregation           int64
# strata_race_label               object
# strata_sex_label                object
# dtype: object

# %%
data.groupby('metric_cat_item_yaxis_label').count()
# Out:
#                                        metric_item_label  metric_cat_label  \
# metric_cat_item_yaxis_label
# Per 1,000                                           1145              1145
# Per 100,000                                        19654             19654
# Years per 100,000 population aged <75               5775              5775
#
#                                        metric_item_label_subtitle  \
# metric_cat_item_yaxis_label
# Per 1,000                                                    1145
# Per 100,000                                                 19654
# Years per 100,000 population aged <75                        5775
#
#                                        geo_label_city  geo_label_state  \
# metric_cat_item_yaxis_label
# Per 1,000                                        1145             1145
# Per 100,000                                     19654            19654
# Years per 100,000 population aged <75            5775             5775
#
#                                        geo_fips_code  value  date_label  \
# metric_cat_item_yaxis_label
# Per 1,000                                       1145   1145        1145
# Per 100,000                                    19654  19654       19654
# Years per 100,000 population aged <75           5775   5775        5775
#
#                                        geo_label_proxy_or_real  \
# metric_cat_item_yaxis_label
# Per 1,000                                                 1145
# Per 100,000                                              19654
# Years per 100,000 population aged <75                     5775
#
#                                        value_95_ci_low  value_95_ci_high  \
# metric_cat_item_yaxis_label
# Per 1,000                                         1145              1145
# Per 100,000                                      19654             19654
# Years per 100,000 population aged <75             5775              5775
#
#                                        geo_strata_region  geo_strata_poverty  \
# metric_cat_item_yaxis_label
# Per 1,000                                           1145                1145
# Per 100,000                                        19654               19654
# Years per 100,000 population aged <75               5775                5775
#
#                                        geo_strata_Population  \
# metric_cat_item_yaxis_label
# Per 1,000                                               1145
# Per 100,000                                            19654
# Years per 100,000 population aged <75                   5775
#
#                                        geo_strata_PopDensity  \
# metric_cat_item_yaxis_label
# Per 1,000                                               1145
# Per 100,000                                            19654
# Years per 100,000 population aged <75                   5775
#
#                                        geo_strata_Segregation  \
# metric_cat_item_yaxis_label
# Per 1,000                                                1145
# Per 100,000                                             19654
# Years per 100,000 population aged <75                    5775
#
#                                        strata_race_label  strata_sex_label
# metric_cat_item_yaxis_label
# Per 1,000                                           1145              1145
# Per 100,000                                        19654             19654
# Years per 100,000 population aged <75               5775              5775

# %% [markdown]
# Firstly, divide all value, metric_cat_item_yaxis_label and value_95_ci_high such as they are on the same level
#
# Values with metric_cat_item_yaxis_label = Per 1,000 -> Divide them by 1'000
#
# Values with metric_cat_item_yaxis_label = Per 100'000 -> Divide them by 1'000

# %%
columns_to_divide = ['value', 'value_95_ci_low', 'value_95_ci_high']

find_1000 = data['metric_cat_item_yaxis_label'] == 'Per 1,000'
data.loc[find_1000, columns_to_divide] /= 1000

find_100000 = data['metric_cat_item_yaxis_label'] == 'Per 100,000'
data.loc[find_100000, columns_to_divide] /= 100000

# %%
data
# Out:
#              metric_item_label            metric_cat_label  \
# 5106    Deaths from All Causes  Life Expectancy and Deaths
# 5107    Deaths from All Causes  Life Expectancy and Deaths
# 5108    Deaths from All Causes  Life Expectancy and Deaths
# 5109    Deaths from All Causes  Life Expectancy and Deaths
# 5110    Deaths from All Causes  Life Expectancy and Deaths
# ...                        ...                         ...
# 148287         Premature Death  Life Expectancy and Deaths
# 148288         Premature Death  Life Expectancy and Deaths
# 148289         Premature Death  Life Expectancy and Deaths
# 148290         Premature Death  Life Expectancy and Deaths
# 148291         Premature Death  Life Expectancy and Deaths
#
#                                metric_item_label_subtitle  \
# 5106    Deaths from all causes (per 100,000 population...
# 5107    Deaths from all causes (per 100,000 population...
# 5108    Deaths from all causes (per 100,000 population...
# 5109    Deaths from all causes (per 100,000 population...
# 5110    Deaths from all causes (per 100,000 population...
# ...                                                   ...
# 148287  Years of potential life lost before age 75 (pe...
# 148288  Years of potential life lost before age 75 (pe...
# 148289  Years of potential life lost before age 75 (pe...
# 148290  Years of potential life lost before age 75 (pe...
# 148291  Years of potential life lost before age 75 (pe...
#
#                   metric_cat_item_yaxis_label geo_label_city geo_label_state  \
# 5106                              Per 100,000        Seattle              WA
# 5107                              Per 100,000     Fort Worth              TX
# 5108                              Per 100,000  Oklahoma City              OK
# 5109                              Per 100,000     Long Beach              CA
# 5110                              Per 100,000       Columbus              OH
# ...                                       ...            ...             ...
# 148287  Years per 100,000 population aged <75  New York City              NY
# 148288  Years per 100,000 population aged <75      Milwaukee              WI
# 148289  Years per 100,000 population aged <75        Houston              TX
# 148290  Years per 100,000 population aged <75      Milwaukee              WI
# 148291  Years per 100,000 population aged <75     Long Beach              CA
#
#         geo_fips_code        value  date_label  geo_label_proxy_or_real  \
# 5106           5363.0     0.004864        2012                        1
# 5107           4827.0     0.009782        2011                        1
# 5108           4055.0     0.003762        2012                        1
# 5109            643.0     0.006167        2012                        1
# 5110           3918.0     0.010482        2010                        1
# ...               ...          ...         ...                      ...
# 148287         3651.0  5786.217877        2020                        1
# 148288         5553.0  7087.929743        2020                        1
# 148289         4835.0  4099.348306        2011                        1
# 148290         5553.0  5706.528569        2014                        1
# 148291          643.0  5316.198034        2015                        1
#
#         value_95_ci_low  value_95_ci_high geo_strata_region  \
# 5106           0.004610          0.005132              West
# 5107           0.009543          0.010025             South
# 5108           0.003207          0.004393             South
# 5109           0.005797          0.006558              West
# 5110           0.009922          0.011068           Midwest
# ...                 ...               ...               ...
# 148287      5668.487295       5903.948459         Northeast
# 148288      6458.346917       7717.512570           Midwest
# 148289      3723.288703       4475.407910             South
# 148290      4594.357077       6818.700061           Midwest
# 148291      4696.310360       5936.085707              West
#
#         geo_strata_poverty  geo_strata_Population  geo_strata_PopDensity  \
# 5106                     1                      1                      1
# 5107                     1                      1                      1
# 5108                     1                      1                      1
# 5109                     1                      1                      1
# 5110                     1                      1                      1
# ...                    ...                    ...                    ...
# 148287                   1                      0                      0
# 148288                   0                      1                      1
# 148289                   1                      0                      1
# 148290                   0                      1                      1
# 148291                   1                      1                      1
#
#         geo_strata_Segregation strata_race_label strata_sex_label
# 5106                         1          Asian/PI             Both
# 5107                         1               All             Male
# 5108                         1          Asian/PI             Both
# 5109                         0          Asian/PI             Both
# 5110                         1             Black             Male
# ...                        ...               ...              ...
# 148287                       0          Hispanic             Both
# 148288                       0          Hispanic             Both
# 148289                       0          Asian/PI             Both
# 148290                       0          Asian/PI             Both
# 148291                       0          Asian/PI             Both
#
# [26574 rows x 19 columns]

# %% [markdown]
# For metric_cat_item_yaxis_label where the input is 'Years per 100,000 population aged <75', we add a new column at the end which will indicate us about the unit of this metric. Where 0 are persons and 1 are years. Furthermore, divide by 100'000 to be on the same scale as the other metrics.

# %%
data['persons_or_years'] = 0
data.loc[data['metric_cat_item_yaxis_label'] == 'Years per 100,000 population aged <75', 'persons_or_years'] = 1

find_years = data['metric_cat_item_yaxis_label'] == 'Years per 100,000 population aged <75'
data.loc[find_years, columns_to_divide] /= 100000

# %%
data
# Out:
#              metric_item_label            metric_cat_label  \
# 5106    Deaths from All Causes  Life Expectancy and Deaths
# 5107    Deaths from All Causes  Life Expectancy and Deaths
# 5108    Deaths from All Causes  Life Expectancy and Deaths
# 5109    Deaths from All Causes  Life Expectancy and Deaths
# 5110    Deaths from All Causes  Life Expectancy and Deaths
# ...                        ...                         ...
# 148287         Premature Death  Life Expectancy and Deaths
# 148288         Premature Death  Life Expectancy and Deaths
# 148289         Premature Death  Life Expectancy and Deaths
# 148290         Premature Death  Life Expectancy and Deaths
# 148291         Premature Death  Life Expectancy and Deaths
#
#                                metric_item_label_subtitle  \
# 5106    Deaths from all causes (per 100,000 population...
# 5107    Deaths from all causes (per 100,000 population...
# 5108    Deaths from all causes (per 100,000 population...
# 5109    Deaths from all causes (per 100,000 population...
# 5110    Deaths from all causes (per 100,000 population...
# ...                                                   ...
# 148287  Years of potential life lost before age 75 (pe...
# 148288  Years of potential life lost before age 75 (pe...
# 148289  Years of potential life lost before age 75 (pe...
# 148290  Years of potential life lost before age 75 (pe...
# 148291  Years of potential life lost before age 75 (pe...
#
#                   metric_cat_item_yaxis_label geo_label_city geo_label_state  \
# 5106                              Per 100,000        Seattle              WA
# 5107                              Per 100,000     Fort Worth              TX
# 5108                              Per 100,000  Oklahoma City              OK
# 5109                              Per 100,000     Long Beach              CA
# 5110                              Per 100,000       Columbus              OH
# ...                                       ...            ...             ...
# 148287  Years per 100,000 population aged <75  New York City              NY
# 148288  Years per 100,000 population aged <75      Milwaukee              WI
# 148289  Years per 100,000 population aged <75        Houston              TX
# 148290  Years per 100,000 population aged <75      Milwaukee              WI
# 148291  Years per 100,000 population aged <75     Long Beach              CA
#
#         geo_fips_code     value  date_label  geo_label_proxy_or_real  \
# 5106           5363.0  0.004864        2012                        1
# 5107           4827.0  0.009782        2011                        1
# 5108           4055.0  0.003762        2012                        1
# 5109            643.0  0.006167        2012                        1
# 5110           3918.0  0.010482        2010                        1
# ...               ...       ...         ...                      ...
# 148287         3651.0  0.057862        2020                        1
# 148288         5553.0  0.070879        2020                        1
# 148289         4835.0  0.040993        2011                        1
# 148290         5553.0  0.057065        2014                        1
# 148291          643.0  0.053162        2015                        1
#
#         value_95_ci_low  value_95_ci_high geo_strata_region  \
# 5106           0.004610          0.005132              West
# 5107           0.009543          0.010025             South
# 5108           0.003207          0.004393             South
# 5109           0.005797          0.006558              West
# 5110           0.009922          0.011068           Midwest
# ...                 ...               ...               ...
# 148287         0.056685          0.059039         Northeast
# 148288         0.064583          0.077175           Midwest
# 148289         0.037233          0.044754             South
# 148290         0.045944          0.068187           Midwest
# 148291         0.046963          0.059361              West
#
#         geo_strata_poverty  geo_strata_Population  geo_strata_PopDensity  \
# 5106                     1                      1                      1
# 5107                     1                      1                      1
# 5108                     1                      1                      1
# 5109                     1                      1                      1
# 5110                     1                      1                      1
# ...                    ...                    ...                    ...
# 148287                   1                      0                      0
# 148288                   0                      1                      1
# 148289                   1                      0                      1
# 148290                   0                      1                      1
# 148291                   1                      1                      1
#
#         geo_strata_Segregation strata_race_label strata_sex_label  \
# 5106                         1          Asian/PI             Both
# 5107                         1               All             Male
# 5108                         1          Asian/PI             Both
# 5109                         0          Asian/PI             Both
# 5110                         1             Black             Male
# ...                        ...               ...              ...
# 148287                       0          Hispanic             Both
# 148288                       0          Hispanic             Both
# 148289                       0          Asian/PI             Both
# 148290                       0          Asian/PI             Both
# 148291                       0          Asian/PI             Both
#
#         persons_or_years
# 5106                   0
# 5107                   0
# 5108                   0
# 5109                   0
# 5110                   0
# ...                  ...
# 148287                 1
# 148288                 1
# 148289                 1
# 148290                 1
# 148291                 1
#
# [26574 rows x 20 columns]

# %% [markdown]
# If we want the initial table just call 'df'

# %%
df = data

# %% [markdown]
# Do label encoding for geo_label_city, geo_label_state

# %%
encoding_columns = ['metric_item_label', 'metric_cat_label', 'metric_item_label_subtitle', 
                    'metric_cat_item_yaxis_label', 'geo_label_city', 'geo_label_city', 'geo_label_state', 'geo_label_state', 
                    'geo_strata_region', 'strata_race_label', 'strata_sex_label']
label_encoder = LabelEncoder()

for column in encoding_columns:
    data[column] = label_encoder.fit_transform(data[column])

data
# Out:
#         metric_item_label  metric_cat_label  metric_item_label_subtitle  \
# 5106                    0                 0                           1
# 5107                    0                 0                           1
# 5108                    0                 0                           1
# 5109                    0                 0                           1
# 5110                    0                 0                           1
# ...                   ...               ...                         ...
# 148287                  6                 0                           6
# 148288                  6                 0                           6
# 148289                  6                 0                           6
# 148290                  6                 0                           6
# 148291                  6                 0                           6
#
#         metric_cat_item_yaxis_label  geo_label_city  geo_label_state  \
# 5106                              1              32               21
# 5107                              1              11               20
# 5108                              1              24               16
# 5109                              1              16                1
# 5110                              1               6               15
# ...                             ...             ...              ...
# 148287                            2              22               14
# 148288                            2              20               22
# 148289                            2              12               20
# 148290                            2              20               22
# 148291                            2              16                1
#
#         geo_fips_code     value  date_label  geo_label_proxy_or_real  \
# 5106           5363.0  0.004864        2012                        1
# 5107           4827.0  0.009782        2011                        1
# 5108           4055.0  0.003762        2012                        1
# 5109            643.0  0.006167        2012                        1
# 5110           3918.0  0.010482        2010                        1
# ...               ...       ...         ...                      ...
# 148287         3651.0  0.057862        2020                        1
# 148288         5553.0  0.070879        2020                        1
# 148289         4835.0  0.040993        2011                        1
# 148290         5553.0  0.057065        2014                        1
# 148291          643.0  0.053162        2015                        1
#
#         value_95_ci_low  value_95_ci_high  geo_strata_region  \
# 5106           0.004610          0.005132                  3
# 5107           0.009543          0.010025                  2
# 5108           0.003207          0.004393                  2
# 5109           0.005797          0.006558                  3
# 5110           0.009922          0.011068                  0
# ...                 ...               ...                ...
# 148287         0.056685          0.059039                  1
# 148288         0.064583          0.077175                  0
# 148289         0.037233          0.044754                  2
# 148290         0.045944          0.068187                  0
# 148291         0.046963          0.059361                  3
#
#         geo_strata_poverty  geo_strata_Population  geo_strata_PopDensity  \
# 5106                     1                      1                      1
# 5107                     1                      1                      1
# 5108                     1                      1                      1
# 5109                     1                      1                      1
# 5110                     1                      1                      1
# ...                    ...                    ...                    ...
# 148287                   1                      0                      0
# 148288                   0                      1                      1
# 148289                   1                      0                      1
# 148290                   0                      1                      1
# 148291                   1                      1                      1
#
#         geo_strata_Segregation  strata_race_label  strata_sex_label  \
# 5106                         1                  1                 0
# 5107                         1                  0                 2
# 5108                         1                  1                 0
# 5109                         0                  1                 0
# 5110                         1                  2                 2
# ...                        ...                ...               ...
# 148287                       0                  3                 0
# 148288                       0                  3                 0
# 148289                       0                  1                 0
# 148290                       0                  1                 0
# 148291                       0                  1                 0
#
#         persons_or_years
# 5106                   0
# 5107                   0
# 5108                   0
# 5109                   0
# 5110                   0
# ...                  ...
# 148287                 1
# 148288                 1
# 148289                 1
# 148290                 1
# 148291                 1
#
# [26574 rows x 20 columns]

# %% [markdown]
# Transform all to float, whis will be easier for later processing

# %%
data = data.astype(float)

# %%
data.dtypes
# Out:
# metric_item_label              float64
# metric_cat_label               float64
# metric_item_label_subtitle     float64
# metric_cat_item_yaxis_label    float64
# geo_label_city                 float64
# geo_label_state                float64
# geo_fips_code                  float64
# value                          float64
# date_label                     float64
# geo_label_proxy_or_real        float64
# value_95_ci_low                float64
# value_95_ci_high               float64
# geo_strata_region              float64
# geo_strata_poverty             float64
# geo_strata_Population          float64
# geo_strata_PopDensity          float64
# geo_strata_Segregation         float64
# strata_race_label              float64
# strata_sex_label               float64
# persons_or_years               float64
# dtype: object

# %% [markdown]
# Our data is now fully numerical and we can work with this.

# %% [markdown]
# ### Analyze the Data with Statistics

# %% [markdown]
# # 4. Feature Selection

# %% [markdown]
# # 5. Model Selection

# %% [markdown]
# # 6. Model Training and Evaluation

# %% [markdown]
# # 7. Hyperparameter Tuning

# %% [markdown]
# # 8. Model Deployment and Monitoring
